# %% [markdown]
# # ***Introduction to Python***

# %%
print('hello world!')
# Out:
# hello world!

# %%
name=str(input('Assalomu alaykum! \nIltimos ismingizni kiriting: '))
print(f'Salom, {name} Pythonga xush kelibsiz!')
# Out:
# Assalomu alaykum!
# Iltimos ismingizni kiriting: Fatima
# Salom, Fatima Pythonga xush kelibsiz!

# %%
car='Tesla'
print(car)
# Out:
# Tesla

# %%
favouriteFruit='apple'
print(f'My favourite fruit is {favouriteFruit}')
# Out:
# My favourite fruit is apple

# %%
float_num=15.35
print(int(float_num))
print(type(float_num))
# Out:
# 15
# <class 'float'>

# %%
favouriteFlavor=input('What is your favourite flavor? ')
print(favouriteFlavor)
# Out:
# What is your favourite flavor? Matcha
# Matcha

# %%
first_c=100>10
second_c=10>100
natija = 'True' if first_c and second_c else 'False'
print(natija)
# Out:
# False
