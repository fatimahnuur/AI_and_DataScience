# %%
import pandas as pd
import numpy as np
import math

# %%
exam_score=pd.DataFrame(np.random.randint(1, 101, 70))#1 dan 100 gacha random raqamlar chiqarish uchun
display(exam_score)
# Out:
#      0
# 0   44
# 1   31
# 2   43
# 3   94
# 4   38
# ..  ..
# 65  91
# 66  70
# 67  54
# 68  90
# 69  95
#
# [70 rows x 1 columns]

# %%
exam_score.mean()
# Out:
# 0    51.185714
# dtype: float64

# %%
exam_score.median()
# Out:
# 0    48.5
# dtype: float64

# %%
exam_score.mode()
# Out:
#      0
# 0   50
# 1   70
# 2   75
# 3   80
# 4  100

# %%
range_exam_score=exam_score.max()-exam_score.min()
range_exam_score
# Out:
# 0    50
# dtype: int64

# %%
exam_score.var()
# Out:
# 0    851.950518
# dtype: float64

# %%
exam_score.std()
# Out:
# 0    29.188191
# dtype: float64

# %%
q1_exam_score=exam_score.quantile(0.25)
q3_exam_score=exam_score.quantile(0.75)
iqr=q1_exam_score-q3_exam_score
iqr
# Out:
# 0   -50.0
# dtype: float64
